# %% [markdown]
# # Make SARS-CoV-2 N protein - Cytokine Complex Tasks
# Note: To be run from `./inputs` folder using a Python kernel with PyMOL installed)

# %%
# !conda install -y -c conda-forge -c schrodinger pymol-bundle pandas
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/colby/SARS-CoV-2_N-Cytokine_Docking/.conda
#
#   added / updated specs:
#     - pandas
#     - pymol-bundle
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     apbs-1.5                   |       h1de35cc_3         258 KB  schrodinger
#     biopython-1.81             |   py39ha30fb19_0         2.6 MB  conda-forge
#     brotli-1.0.9               |       hb7f2c08_8          19 KB  conda-forge
#     brotli-bin-1.0.9           |       hb7f2c08_8          17 KB  conda-forge
#     c-ares-1.19.1              |       h0dc2134_0         101 KB  conda-forge
#     certifi-2023.5.7           |     pyhd8ed1ab_0         149 KB  conda-forge
#     charset-normalizer-3.1.0   |     pyhd8ed1ab_0          44 KB  conda-forge
#     collada2gltf-2.1.4         |       h04f5b5a_0         2.2 MB  schrodinger
#     curl-8.1.1                 |       h6c40b1e_0          84 KB
#     freetype-2.10.4            |       h4cff582_1         890 KB  conda-forge
#     giflib-5.2.1               |       hb7f2c08_3          75 KB  conda-forge
#     glew-2.1.0                 |       h046ec9c_2         692 KB  conda-forge
#     h5py-2.10.0                |nompi_py39h1bb8402_106         941 KB  conda-forge
#     hdf4-4.2.15                |       hefd3b78_3         885 KB  conda-forge
#     hdf5-1.10.6                |nompi_hc5d9132_1114         3.1 MB  conda-forge
#     icu-58.2                   |    h0a44026_1000        22.3 MB  conda-forge
#     idna-3.4                   |     pyhd8ed1ab_0          55 KB  conda-forge
#     jpeg-9e                    |       hb7f2c08_3         226 KB  conda-forge
#     krb5-1.19.4                |       hdba6334_0         1.2 MB
#     lcms2-2.15                 |       h29502cd_0         222 KB  conda-forge
#     lerc-3.0                   |       he9d5cce_0         168 KB
#     libblas-3.9.0              |17_osx64_openblas          14 KB  conda-forge
#     libbrotlicommon-1.0.9      |       hb7f2c08_8          64 KB  conda-forge
#     libbrotlidec-1.0.9         |       hb7f2c08_8          33 KB  conda-forge
#     libbrotlienc-1.0.9         |       hb7f2c08_8         303 KB  conda-forge
#     libcblas-3.9.0             |17_osx64_openblas          14 KB  conda-forge
#     libcurl-8.1.1              |       ha585b31_0         359 KB
#     libdeflate-1.17            |       hac1461d_0          66 KB  conda-forge
#     libedit-3.1.20221030       |       h6c40b1e_0         155 KB
#     libev-4.33                 |       haf1e3a3_1          99 KB  conda-forge
#     libgfortran-5.0.0          |11_3_0_h97931a8_31         156 KB  conda-forge
#     libgfortran5-12.2.0        |      he409387_31         1.5 MB  conda-forge
#     libholoplaycore-0.1.0_rc4  |                0         219 KB  schrodinger
#     libiconv-1.17              |       hac89ed1_0         1.3 MB  conda-forge
#     liblapack-3.9.0            |17_osx64_openblas          14 KB  conda-forge
#     libnetcdf-4.8.1            |nompi_hb4d10b0_100         1.3 MB  conda-forge
#     libnghttp2-1.46.0          |       ha29bfda_0         687 KB
#     libopenblas-0.3.23         |openmp_h429af6e_0         5.7 MB  conda-forge
#     libpng-1.6.39              |       h6c40b1e_0         290 KB
#     libssh2-1.10.0             |       h0a4fc7d_0         258 KB
#     libtiff-4.5.0              |       hcec6c5f_2         498 KB
#     libwebp-1.2.4              |       h70a068d_1          76 KB  conda-forge
#     libwebp-base-1.2.4         |       h6c40b1e_1         367 KB
#     libxml2-2.9.14             |       hbf8cd5e_0         641 KB
#     libzip-1.8.0               |       h272c8d6_0         115 KB
#     llvm-openmp-16.0.5         |       hff08bdf_0         289 KB  conda-forge
#     lz4-c-1.9.4                |       hf0c8a7f_0         153 KB  conda-forge
#     mengine-1                  |       h1de35cc_1         292 KB  schrodinger
#     mmcif_pdbx-2.0.0           |     pyh44b312d_0          24 KB  conda-forge
#     mpeg_encode-1              |       h1de35cc_1         103 KB  schrodinger
#     mtz2ccp4_px-1.1            |       h36550e2_0         536 KB  schrodinger
#     numpy-1.23.5               |   py39hdfa1d0c_0         5.3 MB  conda-forge
#     pandas-2.0.0               |   py39hecff1ad_0        10.9 MB  conda-forge
#     pdb2pqr-3.6.1              |     pyhd8ed1ab_0         150 KB  conda-forge
#     pillow-9.4.0               |   py39hcec6c5f_0         691 KB
#     pmw-2.0.1                  |py39h6e9494a_1007         509 KB  conda-forge
#     propka-3.5.0               |   py39h2a79d86_0         162 KB  conda-forge
#     pycollada-0.7.2            |     pyhd8ed1ab_0          84 KB  conda-forge
#     pykerberos-1.2.4           |   py39hada4101_2          25 KB  conda-forge
#     pymol-2.5.5                |   py39h7ff3e86_6         8.8 MB  schrodinger
#     pymol-bundle-2.5.5         |                3          18 KB  schrodinger
#     pymol-web-examples-2.4     |                1         1.9 MB  schrodinger
#     pysocks-1.7.1              |     pyha2e5f31_6          19 KB  conda-forge
#     python-tzdata-2023.3       |     pyhd8ed1ab_0         140 KB  conda-forge
#     pytz-2023.3                |     pyhd8ed1ab_0         182 KB  conda-forge
#     requests-2.31.0            |     pyhd8ed1ab_0          55 KB  conda-forge
#     rigimol-1.3                |                2         530 KB  schrodinger
#     urllib3-2.0.2              |     pyhd8ed1ab_0          95 KB  conda-forge
#     vtk-m-1.5.1                |       h0a44026_1         3.6 MB  schrodinger
#     zstd-1.5.5                 |       hc035e20_0         608 KB
#     ------------------------------------------------------------
#                                            Total:        85.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   apbs               schrodinger/osx-64::apbs-1.5-h1de35cc_3 None
#   biopython          conda-forge/osx-64::biopython-1.81-py39ha30fb19_0 None
#   brotli             conda-forge/osx-64::brotli-1.0.9-hb7f2c08_8 None
#   brotli-bin         conda-forge/osx-64::brotli-bin-1.0.9-hb7f2c08_8 None
#   bzip2              conda-forge/osx-64::bzip2-1.0.8-h0d85af4_4 None
#   c-ares             conda-forge/osx-64::c-ares-1.19.1-h0dc2134_0 None
#   certifi            conda-forge/noarch::certifi-2023.5.7-pyhd8ed1ab_0 None
#   charset-normalizer conda-forge/noarch::charset-normalizer-3.1.0-pyhd8ed1ab_0 None
#   collada2gltf       schrodinger/osx-64::collada2gltf-2.1.4-h04f5b5a_0 None
#   curl               pkgs/main/osx-64::curl-8.1.1-h6c40b1e_0 None
#   freetype           conda-forge/osx-64::freetype-2.10.4-h4cff582_1 None
#   giflib             conda-forge/osx-64::giflib-5.2.1-hb7f2c08_3 None
#   glew               conda-forge/osx-64::glew-2.1.0-h046ec9c_2 None
#   h5py               conda-forge/osx-64::h5py-2.10.0-nompi_py39h1bb8402_106 None
#   hdf4               conda-forge/osx-64::hdf4-4.2.15-hefd3b78_3 None
#   hdf5               conda-forge/osx-64::hdf5-1.10.6-nompi_hc5d9132_1114 None
#   icu                conda-forge/osx-64::icu-58.2-h0a44026_1000 None
#   idna               conda-forge/noarch::idna-3.4-pyhd8ed1ab_0 None
#   jpeg               conda-forge/osx-64::jpeg-9e-hb7f2c08_3 None
#   krb5               pkgs/main/osx-64::krb5-1.19.4-hdba6334_0 None
#   lcms2              conda-forge/osx-64::lcms2-2.15-h29502cd_0 None
#   lerc               pkgs/main/osx-64::lerc-3.0-he9d5cce_0 None
#   libblas            conda-forge/osx-64::libblas-3.9.0-17_osx64_openblas None
#   libbrotlicommon    conda-forge/osx-64::libbrotlicommon-1.0.9-hb7f2c08_8 None
#   libbrotlidec       conda-forge/osx-64::libbrotlidec-1.0.9-hb7f2c08_8 None
#   libbrotlienc       conda-forge/osx-64::libbrotlienc-1.0.9-hb7f2c08_8 None
#   libcblas           conda-forge/osx-64::libcblas-3.9.0-17_osx64_openblas None
#   libcurl            pkgs/main/osx-64::libcurl-8.1.1-ha585b31_0 None
#   libdeflate         conda-forge/osx-64::libdeflate-1.17-hac1461d_0 None
#   libedit            pkgs/main/osx-64::libedit-3.1.20221030-h6c40b1e_0 None
#   libev              conda-forge/osx-64::libev-4.33-haf1e3a3_1 None
#   libgfortran        conda-forge/osx-64::libgfortran-5.0.0-11_3_0_h97931a8_31 None
#   libgfortran5       conda-forge/osx-64::libgfortran5-12.2.0-he409387_31 None
#   libholoplaycore    schrodinger/osx-64::libholoplaycore-0.1.0_rc4-0 None
#   libiconv           conda-forge/osx-64::libiconv-1.17-hac89ed1_0 None
#   liblapack          conda-forge/osx-64::liblapack-3.9.0-17_osx64_openblas None
#   libnetcdf          conda-forge/osx-64::libnetcdf-4.8.1-nompi_hb4d10b0_100 None
#   libnghttp2         pkgs/main/osx-64::libnghttp2-1.46.0-ha29bfda_0 None
#   libopenblas        conda-forge/osx-64::libopenblas-0.3.23-openmp_h429af6e_0 None
#   libpng             pkgs/main/osx-64::libpng-1.6.39-h6c40b1e_0 None
#   libssh2            pkgs/main/osx-64::libssh2-1.10.0-h0a4fc7d_0 None
#   libtiff            pkgs/main/osx-64::libtiff-4.5.0-hcec6c5f_2 None
#   libwebp            conda-forge/osx-64::libwebp-1.2.4-h70a068d_1 None
#   libwebp-base       pkgs/main/osx-64::libwebp-base-1.2.4-h6c40b1e_1 None
#   libxml2            pkgs/main/osx-64::libxml2-2.9.14-hbf8cd5e_0 None
#   libzip             pkgs/main/osx-64::libzip-1.8.0-h272c8d6_0 None
#   llvm-openmp        conda-forge/osx-64::llvm-openmp-16.0.5-hff08bdf_0 None
#   lz4-c              conda-forge/osx-64::lz4-c-1.9.4-hf0c8a7f_0 None
#   mengine            schrodinger/osx-64::mengine-1-h1de35cc_1 None
#   mmcif_pdbx         conda-forge/noarch::mmcif_pdbx-2.0.0-pyh44b312d_0 None
#   mpeg_encode        schrodinger/osx-64::mpeg_encode-1-h1de35cc_1 None
#   mtz2ccp4_px        schrodinger/osx-64::mtz2ccp4_px-1.1-h36550e2_0 None
#   numpy              conda-forge/osx-64::numpy-1.23.5-py39hdfa1d0c_0 None
#   pandas             conda-forge/osx-64::pandas-2.0.0-py39hecff1ad_0 None
#   pdb2pqr            conda-forge/noarch::pdb2pqr-3.6.1-pyhd8ed1ab_0 None
#   pillow             pkgs/main/osx-64::pillow-9.4.0-py39hcec6c5f_0 None
#   pmw                conda-forge/osx-64::pmw-2.0.1-py39h6e9494a_1007 None
#   propka             conda-forge/osx-64::propka-3.5.0-py39h2a79d86_0 None
#   pycollada          conda-forge/noarch::pycollada-0.7.2-pyhd8ed1ab_0 None
#   pykerberos         conda-forge/osx-64::pykerberos-1.2.4-py39hada4101_2 None
#   pymol              schrodinger/osx-64::pymol-2.5.5-py39h7ff3e86_6 None
#   pymol-bundle       schrodinger/osx-64::pymol-bundle-2.5.5-3 None
#   pymol-web-examples schrodinger/noarch::pymol-web-examples-2.4-1 None
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyha2e5f31_6 None
#   python-tzdata      conda-forge/noarch::python-tzdata-2023.3-pyhd8ed1ab_0 None
#   pytz               conda-forge/noarch::pytz-2023.3-pyhd8ed1ab_0 None
#   requests           conda-forge/noarch::requests-2.31.0-pyhd8ed1ab_0 None
#   rigimol            schrodinger/osx-64::rigimol-1.3-2 None
#   urllib3            conda-forge/noarch::urllib3-2.0.2-pyhd8ed1ab_0 None
#   vtk-m              schrodinger/osx-64::vtk-m-1.5.1-h0a44026_1 None
#   zstd               pkgs/main/osx-64::zstd-1.5.5-hc035e20_0 None
#
#
#
# Downloading and Extracting Packages
# curl-8.1.1           | 84 KB     | ##################################### | 100%
# pandas-2.0.0         | 10.9 MB   | ##################################### | 100%
# charset-normalizer-3 | 44 KB     | ##################################### | 100%
# propka-3.5.0         | 162 KB    | ##################################### | 100%
# numpy-1.23.5         | 5.3 MB    | ##################################### | 100%
# libiconv-1.17        | 1.3 MB    | ##################################### | 100%
# libgfortran-5.0.0    | 156 KB    | ##################################### | 100%
# libev-4.33           | 99 KB     | ##################################### | 100%
# libtiff-4.5.0        | 498 KB    | ##################################### | 100%
# mmcif_pdbx-2.0.0     | 24 KB     | ##################################### | 100%
# libcurl-8.1.1        | 359 KB    | ##################################### | 100%
# h5py-2.10.0          | 941 KB    | ##################################### | 100%
# krb5-1.19.4          | 1.2 MB    | ##################################### | 100%
# idna-3.4             | 55 KB     | ##################################### | 100%
# vtk-m-1.5.1          | 3.6 MB    | ##################################### | 100%
# libssh2-1.10.0       | 258 KB    | ##################################### | 100%
# libopenblas-0.3.23   | 5.7 MB    | ##################################### | 100%
# urllib3-2.0.2        | 95 KB     | ##################################### | 100%
# jpeg-9e              | 226 KB    | ##################################### | 100%
# biopython-1.81       | 2.6 MB    | ##################################### | 100%
# icu-58.2             | 22.3 MB   | ##################################### | 100%
# glew-2.1.0           | 692 KB    | ##################################### | 100%
# pymol-2.5.5          | 8.8 MB    | ##################################### | 100%
# pymol-bundle-2.5.5   | 18 KB     | ##################################### | 100%
# libbrotlidec-1.0.9   | 33 KB     | ##################################### | 100%
# lerc-3.0             | 168 KB    | ##################################### | 100%
# pmw-2.0.1            | 509 KB    | ##################################### | 100%
# certifi-2023.5.7     | 149 KB    | ##################################### | 100%
# zstd-1.5.5           | 608 KB    | ##################################### | 100%
# libedit-3.1.20221030 | 155 KB    | ##################################### | 100%
# libholoplaycore-0.1. | 219 KB    | ##################################### | 100%
# libwebp-1.2.4        | 76 KB     | ##################################### | 100%
# liblapack-3.9.0      | 14 KB     | ##################################### | 100%
# libblas-3.9.0        | 14 KB     | ##################################### | 100%
# libgfortran5-12.2.0  | 1.5 MB    | ##################################### | 100%
# pytz-2023.3          | 182 KB    | ##################################### | 100%
# brotli-1.0.9         | 19 KB     | ##################################### | 100%
# lcms2-2.15           | 222 KB    | ##################################### | 100%
# python-tzdata-2023.3 | 140 KB    | ##################################### | 100%
# pykerberos-1.2.4     | 25 KB     | ##################################### | 100%
# mtz2ccp4_px-1.1      | 536 KB    | ##################################### | 100%
# requests-2.31.0      | 55 KB     | ##################################### | 100%
# pymol-web-examples-2 | 1.9 MB    | ##################################### | 100%
# pycollada-0.7.2      | 84 KB     | ##################################### | 100%
# libcblas-3.9.0       | 14 KB     | ##################################### | 100%
# libnghttp2-1.46.0    | 687 KB    | ##################################### | 100%
# c-ares-1.19.1        | 101 KB    | ##################################### | 100%
# libnetcdf-4.8.1      | 1.3 MB    | ##################################### | 100%
# pdb2pqr-3.6.1        | 150 KB    | ##################################### | 100%
# hdf4-4.2.15          | 885 KB    | ##################################### | 100%
# brotli-bin-1.0.9     | 17 KB     | ##################################### | 100%
# lz4-c-1.9.4          | 153 KB    | ##################################### | 100%
# libbrotlicommon-1.0. | 64 KB     | ##################################### | 100%
# giflib-5.2.1         | 75 KB     | ##################################### | 100%
# apbs-1.5             | 258 KB    | ##################################### | 100%
# libdeflate-1.17      | 66 KB     | ##################################### | 100%
# libbrotlienc-1.0.9   | 303 KB    | ##################################### | 100%
# libwebp-base-1.2.4   | 367 KB    | ##################################### | 100%
# hdf5-1.10.6          | 3.1 MB    | ##################################### | 100%
# mengine-1            | 292 KB    | ##################################### | 100%
# libzip-1.8.0         | 115 KB    | ##################################### | 100%
# pysocks-1.7.1        | 19 KB     | ##################################### | 100%
# pillow-9.4.0         | 691 KB    | ##################################### | 100%
# libxml2-2.9.14       | 641 KB    | ##################################### | 100%
# libpng-1.6.39        | 290 KB    | ##################################### | 100%
# collada2gltf-2.1.4   | 2.2 MB    | ##################################### | 100%
# freetype-2.10.4      | 890 KB    | ##################################### | 100%
# rigimol-1.3          | 530 KB    | ##################################### | 100%
# mpeg_encode-1        | 103 KB    | ##################################### | 100%
# llvm-openmp-16.0.5   | 289 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done

# %%
import os, shutil, sys
import pandas as pd
from itertools import product
from pymol import cmd
from random import sample

# %%
## List N protein files
n_files = os.listdir('./N-Proteins/')
n_files = [x.replace('.pdb', '') for x in n_files]

## TEMP SUBSET FOR TESTING
n_files = ['SARS-CoV-2-WA1-N', 'SARS-CoV-2-XBB-N']

## List Cytokine files
cytokine_files = os.listdir('./Cytokines/')
cytokine_files = [x.replace('.pdb', '') for x in cytokine_files]

## TEMP SUBSET FOR TESTING
cytokine_files = ['CXCL12alpha', 'CXCL12beta']

files_dict = {
    'n_protein': n_files,
    'cytokine_protein': cytokine_files
}

print(files_dict)
# Out:
# {'n_protein': ['SARS-CoV-2-WA1-N', 'SARS-CoV-2-XBB-N'], 'cytokine_protein': ['CXCL12alpha', 'CXCL12beta']}

# %%
## Prepare Task DataFrame
task_grid = pd.DataFrame([row for row in product(*files_dict.values())], columns=files_dict.keys())

task_grid['complex_id'] = task_grid['n_protein'].replace('SARS-CoV-2-N-', '') + "__" + task_grid['cytokine_protein']
task_grid['n_pdb'] = task_grid['n_protein'] + ".pdb"
task_grid['cytokine_pdb'] = task_grid['cytokine_protein'] + ".pdb"

## Make Empty Columns
task_grid['experiment_path'] = ''
task_grid['n_residues'] = ''
task_grid['cytokine_residues'] = ''

## Reorder Columns
task_grid = task_grid[[
    'complex_id',
    'experiment_path',
    'n_protein', 'n_pdb', 'n_residues',
    'cytokine_protein', 'cytokine_pdb', 'cytokine_residues'
    ]]

display(task_grid)
# Out:
#                       complex_id experiment_path         n_protein
# 0  SARS-CoV-2-WA1-N__CXCL12alpha                  SARS-CoV-2-WA1-N  \
# 1   SARS-CoV-2-WA1-N__CXCL12beta                  SARS-CoV-2-WA1-N
# 2  SARS-CoV-2-XBB-N__CXCL12alpha                  SARS-CoV-2-XBB-N
# 3   SARS-CoV-2-XBB-N__CXCL12beta                  SARS-CoV-2-XBB-N
#
#                   n_pdb n_residues cytokine_protein     cytokine_pdb
# 0  SARS-CoV-2-WA1-N.pdb                 CXCL12alpha  CXCL12alpha.pdb  \
# 1  SARS-CoV-2-WA1-N.pdb                  CXCL12beta   CXCL12beta.pdb
# 2  SARS-CoV-2-XBB-N.pdb                 CXCL12alpha  CXCL12alpha.pdb
# 3  SARS-CoV-2-XBB-N.pdb                  CXCL12beta   CXCL12beta.pdb
#
#   cytokine_residues
# 0
# 1
# 2
# 3

# %%
## Define Helper Functions

## Find Random Surface Residues
def find_random_surface_residues(file, percentage = 0.25):
    cmd.load(file)
    ## Finds atoms on the surface of a protein
    ## Logic from: https://pymolwiki.org/index.php/FindSurfaceResidues
    cutoff = 2.0
    tmpObj = cmd.get_unused_name("_tmp")
    cmd.create(tmpObj, "(all) and polymer", zoom=0)
    cmd.set("dot_solvent", 1, tmpObj)
    cmd.get_area(selection=tmpObj, load_b=1)
    cmd.remove(tmpObj + " and b < " + str(cutoff))
    cmd.select("exposed_atoms", "(all) in " + tmpObj)
    cmd.delete(tmpObj)
    ## Get a list of residue numbers and then subset it
    surface_residues = set()
    cmd.iterate('exposed_atoms', "surface_residues.add(resi)", space=locals())
    k = int(len(surface_residues) * percentage)
    surface_residues_sample = list(sample(surface_residues, k))
    surface_residues_sample = [int(x) for x in surface_residues_sample]
    surface_residues_sample.sort()
    ## Reintialize Everything
    cmd.reinitialize(what='everything')
    return surface_residues_sample

## Write AIR File
def write_air_file(active1, passive1, active2, passive2, segid1='A', segid2='B', output_file = "air.tbl"):

    active1 = [int(x) for x in active1]
    passive1 = [int(x) for x in passive1]
    active2 = [int(x) for x in active2]
    passive2 = [int(x) for x in passive2]

    all1 = active1 + passive1
    all2 = active2 + passive2

    param_lines = []

    for resi1 in active1:
        param_lines.append('assign (resi {:d} and segid {:s})'.format(resi1, segid1))
        param_lines.append('(')
        c = 0
        for resi2 in all2:
            param_lines.append('       (resi {:d} and segid {:s})'.format(resi2, segid2))
            c += 1
            if c != len(all2):
                param_lines.append('        or')
        param_lines.append(') 2.0 2.0 0.0\n')
            
    for resi2 in active2:
        param_lines.append('assign (resi {:d} and segid {:s})'.format(resi2, segid2))
        param_lines.append('(\n')
        c = 0
        for resi1 in all1:
            param_lines.append('       (resi {:d} and segid {:s})'.format(resi1, segid1))
            c += 1
            if c != len(all1):
                param_lines.append('        or\n')
        param_lines.append(') 2.0 2.0 0.0\n')
    
    f = open(output_file, "w")
    f.writelines("\n".join(param_lines))
    f.close()

## Write run.param file
def write_run_params(ambig_tbl = None,
                     haddock_dir = "/root/haddock/haddock2.4-2021-01/",
                     n_comp = 2,
                     pdb_file_1 = "",
                     pdb_file_2 = "",
                     project_dir = "./",
                     prot_segid_1 = "A",
                     prot_segid_2 = "B",
                     run_number = 1,
                     output_file = "run.param"):
    param_lines  = [
        f"HADDOCK_DIR={haddock_dir}",
        f"N_COMP={n_comp}",
        f"PDB_FILE1={pdb_file_1}",
        f"PDB_FILE2={pdb_file_2}",
        f"PROJECT_DIR={project_dir}",
        f"PROT_SEGID_1={prot_segid_1}",
        f"PROT_SEGID_2={prot_segid_2}",
        f"RUN_NUMBER={run_number}",
    ]
    if ambig_tbl:
        param_lines = [f"AMBIG_TBL={ambig_tbl}", *param_lines]
    # print(param_lines)
    # return(param_lines)
    f = open(output_file, "w")
    f.writelines("\n".join(param_lines))
    f.close()
    return(True)

# %%
## Setup Experiment Paths
root_path = '../cluster_tests/'

for index, complex in task_grid.iterrows():
    print(f"Prepping: {complex['complex_id']}...\n")
    experiment_path = root_path + complex['complex_id']
    task_grid.at[index,'experiment_path'] = experiment_path

    ## Make Experiment Folder
    os.makedirs(experiment_path, exist_ok = True)

    ## Copy PDBs
    print("Copying PDB files...")
    shutil.copyfile("./N-Proteins/" + complex['n_pdb'],
                    experiment_path + "/" + complex['n_pdb'])
    shutil.copyfile("./Cytokines/" + complex['cytokine_pdb'],
                    experiment_path + "/" + complex['cytokine_pdb'])
    
    ## Copy ana_scripts folder
    print("Copying ana_scripts folder...")
    shutil.copytree("../helper_scripts/ana_scripts/",
                    experiment_path + "/ana_scripts/")
    
    ## Make run.cns.path file
    shutil.copyfile("../helper_scripts/run.cns.patch",
                    experiment_path + "/run.cns.patch")
    
    ## Make run-docking.csh file
    shutil.copyfile("../helper_scripts/run-docking.csh",
                    experiment_path + "/run-docking.csh")
#     print("Writing run-docking.csh file...")
#     run_docking_csh_file = open(f"{experiment_path}/run-docking.csh","w")
#     run_commands = [
# f'''#!/bin/csh
# #
# source $HOME/haddock/haddock2.4-2021-01/haddock_configure.csh
# echo "====================================================================="
# echo "====================================================================="
# echo " RUNNING: {complex['complex_id']} PROTEIN-PROTEIN DOCKING "
# echo "====================================================================="
# echo "====================================================================="
# haddock2.4 >&/dev/null
# cd run1
# patch -p0 -i ../run.cns.patch >&/dev/null
# haddock2.4 >&haddock.out
# cd ..
# ./ana_scripts/run_all.csh run1 >&/dev/null
# ../results-stats.csh run1
# echo "====================================================================="
# echo "====================================================================="
# echo " DONE: {complex['complex_id']} PROTEIN-PROTEIN DOCKING COMPLETED  "
# echo "====================================================================="
# echo "====================================================================="
# '''
#     ]
#     run_docking_csh_file.writelines(run_commands)
#     run_docking_csh_file.close()
    
    ## Define Random Restraints
    print("Finding random N surface residues...")
    N_residues = find_random_surface_residues(file = f"./N-Proteins/{complex['n_pdb']}", percentage = 0.25)
    task_grid.at[index,'n_residues'] = '`' + str(','.join(str(x) for x in N_residues))
    print("Finding random Cytokine surface residues...")
    cytokine_residues = find_random_surface_residues(file = f"./Cytokines/{complex['cytokine_pdb']}", percentage = 0.25)
    task_grid.at[index,'cytokine_residues'] = f"`{','.join(str(x) for x in cytokine_residues)}"

    ## Write out AIR file
    print("Writing AIR file...")
    write_air_file(active1 = N_residues,
                   passive1 = [],
                   active2 = cytokine_residues,
                   passive2 = [],
                   segid1='A', segid2='B',
                   output_file = f"{experiment_path}/air.tbl")

    ## Make run.param file
    print("Writing run.param file...")
    write_run_params(ambig_tbl = "./air.tbl",
                    haddock_dir = "/root/haddock/haddock2.4-2021-01/",
                    n_comp = 2,
                    pdb_file_1 = f"./{complex['n_pdb']}",
                    pdb_file_2 = f"./{complex['cytokine_pdb']}",
                    project_dir = "./",
                    prot_segid_1 = "A",
                    prot_segid_2 = "B",
                    run_number = 1,
                    output_file = f"{experiment_path}/run.param")
    
    print(f"Finished Prepping: {complex['complex_id']}.\n")
# Out:
# Prepping: SARS-CoV-2-WA1-N__CXCL12alpha...
#
# Copying PDB files...
# Copying ana_scripts folder...
# Finding random N surface residues...
# /var/folders/__/1v5xyw5s0tl2z88yrm0lb4d40000gn/T/ipykernel_7148/768050655.py:20: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   surface_residues_sample = list(sample(surface_residues, k))
# Finding random Cytokine surface residues...
# Writing AIR file...
# Writing run.param file...
# Finished Prepping: SARS-CoV-2-WA1-N__CXCL12alpha.
#
# Prepping: SARS-CoV-2-WA1-N__CXCL12beta...
#
# Copying PDB files...
# Copying ana_scripts folder...
# Finding random N surface residues...
# Finding random Cytokine surface residues...
# Writing AIR file...
# Writing run.param file...
# Finished Prepping: SARS-CoV-2-WA1-N__CXCL12beta.
#
# Prepping: SARS-CoV-2-XBB-N__CXCL12alpha...
#
# Copying PDB files...
# Copying ana_scripts folder...
# Finding random N surface residues...
# Finding random Cytokine surface residues...
# Writing AIR file...
# Writing run.param file...
# Finished Prepping: SARS-CoV-2-XBB-N__CXCL12alpha.
#
# Prepping: SARS-CoV-2-XBB-N__CXCL12beta...
#
# Copying PDB files...
# Copying ana_scripts folder...
# Finding random N surface residues...
# Finding random Cytokine surface residues...
# Writing AIR file...
# Writing run.param file...
# Finished Prepping: SARS-CoV-2-XBB-N__CXCL12beta.

# %%
## Create Analysis CSV
task_grid.to_csv(f'{root_path}/analyses.csv', index=False)
